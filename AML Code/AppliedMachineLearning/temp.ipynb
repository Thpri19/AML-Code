# %%
import numpy as np
import matplotlib.pyplot as plt

def f(p,I):
    return I/p 


xlist = np.linspace(0,1, num=1000)
ylist = f(xlist,225)

plt.figure(num=0,dpi=120)
plt.plot(xlist,ylist)
plt.xlabel(r"Probability of Hard Work $p_H$")
plt.ylabel(r"Minimum required income")
# Out:
# C:\Users\computer\AppData\Local\Temp\ipykernel_16456\3792409891.py:5: RuntimeWarning: divide by zero encountered in divide
#   return I/p
# Text(0, 0.5, 'minimum required income')
